# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

data = pd.read_csv('annual-working-hours-per-worker.csv', index_col='Entity')

years = data.iterrows
# Convert year values to integers, saving results back to dataframe

# data.iterrows = years.astype(int)

data.loc['Argentina'].plot(x = "Year")
